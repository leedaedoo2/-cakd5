# %%
import pandas as pd
import numpy as np


df = pd.read_csv('./dataset/auto-mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
# mpg를 kpl로 환산하여 새로운 열을 생성하고 처음 3개 행을 소수점 아래 둘째 자리에서 반올림하여 출력

# %%
#mpg : kpl = 1: 0.425144
df['kpl'] = df.mpg*0.425144
df.loc[[0,1,2],['kpl']]=df.loc[[0,1,2],['kpl']].round(1)
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name       kpl
# 0       1  chevrolet chevelle malibu  7.700000
# 1       1          buick skylark 320  6.400000
# 2       1         plymouth satellite  7.700000
# 3       1              amc rebel sst  6.802304
# 4       1                ford torino  7.227448

# %%
df['horsepower'] = np.where(df['horsepower']=='?',np.nan,df.horsepower)
df['horsepower']=df.horsepower.astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
#  9   kpl           398 non-null    float64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 31.2+ KB

# %%
# horsepower 열을 체크해서 전처리가 필요한 사항을 기술하세요
#hint : np.nan으로 대체
checklist = list(df['horsepower'])
for i in range(len(checklist)):
    if checklist[i] == '?':
        checklist[i] = np.nan
    else:
        checklist[i] = int(checklist[i])
df.horsepower = pd.Series(checklist)
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.info() #horsepower 값에서 null값 발생 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
#  9   kpl           398 non-null    float64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 31.2+ KB

# %%
#horsepower열의 자료형 타입 문제를 해결하고 nan 값의 개수를 출력하세요
df.horsepower.isnull().sum()
# Out:
# 6

# %%
# auto_df를 바이너리 파일로 auto_df.pkl로 저장 후 다시 불러오세요

# %%
import pickle
auto_df = pd.read_csv('./dataset/auto-mpg.csv')
auto_df.to_pickle('./dataset/auto_df.pkl')
auto_df = pd.read_pickle('./dataset/auto_df.pkl')
auto_df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
# horsepower열의 최대값의 절대값으로 horsepower열의 모든 데이터를 나눠서 저장하세요

# %%
df1 = df.copy()
max_value = df1.horsepower.max()
df1.horsepower /= max_value
df1
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0    0.565217    3504          12.0
# 1    15.0          8         350.0    0.717391    3693          11.5
# 2    18.0          8         318.0    0.652174    3436          11.0
# 3    16.0          8         304.0    0.652174    3433          12.0
# 4    17.0          8         302.0    0.608696    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0    0.373913    2790          15.6
# 394  44.0          4          97.0    0.226087    2130          24.6
# 395  32.0          4         135.0    0.365217    2295          11.6
# 396  28.0          4         120.0    0.343478    2625          18.6
# 397  31.0          4         119.0    0.356522    2720          19.4
#
#      model year  origin                   car name        kpl
# 0            70       1  chevrolet chevelle malibu   7.700000
# ...

# %%
# horsepower 각 열 데이터에서 해당 열의 최소값을 뺀 값을 분자,해당 열의 최대값- 최소값을 분모로 계산하여 저장하세요

# %%
def cal(x):
    return (x-x.min())/(x.max()-x.min())

df2 = df.copy()
df2[['horsepower']].apply(lambda x : cal(x))
# Out:
#      horsepower
# 0      0.456522
# 1      0.646739
# 2      0.565217
# 3      0.565217
# 4      0.510870
# ..          ...
# 393    0.217391
# 394    0.032609
# 395    0.206522
# 396    0.179348
# 397    0.195652
#
# [398 rows x 1 columns]

# %%
df2.horsepower.plot()
# Out:
# <AxesSubplot:>

# %%
# origin 열의 고유값을 출력하세요

# %%
df.origin.unique()
# Out:
# array([1, 3, 2], dtype=int64)

# %%
# 정수형데이터를 문자형 데이터로 변환한 후 고유값을 출력하세요(1:'USA',2:'EU',3:'JAPAN')

# %%
df.origin.replace(1,'USA',inplace = True)
df.origin.replace(2,'EU',inplace = True)
df.origin.replace(3,'JAPAN',inplace = True)
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year origin                   car name
# 0            70    USA  chevrolet chevelle malibu
# ...

# %%
#origin 열의 자료형을 확인하고 범주형으로 변환하여 출력
df.origin.astype('category')
print(df.origin)
# Out:
# 0      USA
# 1      USA
# 2      USA
# 3      USA
# 4      USA
#       ...
# 393    USA
# 394     EU
# 395    USA
# 396    USA
# 397    USA
# Name: origin, Length: 398, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   car name      398 non-null    object
#  9   kpl           398 non-null    float64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 31.2+ KB

# %%
def origincat(x):
    cat = ''
    if x == 'USA':
        cat = 'USA'
    elif x == 'EU':
        cat = 'EU'
    elif x == 'JAPAN':
        cat = 'JAPAN'
    return cat

df['origin'] = df.origin.apply(lambda x:origincat(x))
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year origin                   car name        kpl
# 0            70    USA  chevrolet chevelle malibu   7.700000
# ...

# %%
# origin 열을 범주형에서 문자열로 변환한 후 자료형을 출력하세요

# %%
df.origin.astype('str')
# Out:
# 0      USA
# 1      USA
# 2      USA
# 3      USA
# 4      USA
#       ...
# 393    USA
# 394     EU
# 395    USA
# 396    USA
# 397    USA
# Name: origin, Length: 398, dtype: object

# %%
# horsepower를 3개의 bin으로 나누고 bin_names['저출력','보통출력','고출력']으로 출력하세요
# np.histogram() 함수로 3개의 bin으로 나눔

# %%
df5 = df.copy()
df5.horsepower.replace(np.nan,0,inplace = True)


arr = np.array(df5.horsepower)
histogram = np.histogram(arr,bins = 3)
print(histogram)
def horseCat(x):
    cat = ''
    if x >= histogram[1][0] and x <= histogram[1][1]:
        cat = '저출력'
    elif x>= histogram[1][1] and x <= histogram[1][2]:
        cat = '보통출력'
    elif x>= histogram[1][2] and x <= histogram[1][3]:
        cat = '고출력'
    return cat

df['horse_cat'] = df.horsepower.apply(lambda x : horseCat(x))
display(df['horse_cat'])
# Out:
# (array([109, 247,  42], dtype=int64), array([  0.        ,  76.66666667, 153.33333333, 230.        ]))
# 0      보통출력
# 1       고출력
# 2      보통출력
# 3      보통출력
# 4      보통출력
#        ...
# 393    보통출력
# 394     저출력
# 395    보통출력
# 396    보통출력
# 397    보통출력
# Name: horse_cat, Length: 398, dtype: object

# %%
import numpy as np
count,bin_dividers = np.histogram(np.array(new_auto_df.horsepower),
                bins=3,
                range=[new_auto_df.horsepower.min(),new_auto_df.horsepower.max()],
                normed=None,
                weights=None,
                density=None)
print(bin_dividers)
bin_names = ['저출력','보통출력','고출력']
pd.cut(x=new_auto_df.horsepower,bins=bin_dividers,labels=bin_names,include_lowest=True)

# %%
#horsepower 열의 최대값의 절대값으로 모든 데이터를 나누는 정규화를 수행한 후 통계요약표를 출력
display(df1)
display(df1.describe())
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0    0.565217    3504          12.0
# 1    15.0          8         350.0    0.717391    3693          11.5
# 2    18.0          8         318.0    0.652174    3436          11.0
# 3    16.0          8         304.0    0.652174    3433          12.0
# 4    17.0          8         302.0    0.608696    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0    0.373913    2790          15.6
# 394  44.0          4          97.0    0.226087    2130          24.6
# 395  32.0          4         135.0    0.365217    2295          11.6
# 396  28.0          4         120.0    0.343478    2625          18.6
# 397  31.0          4         119.0    0.356522    2720          19.4
#
#      model year  origin                   car name        kpl
# 0            70       1  chevrolet chevelle malibu   7.700000
# ...
