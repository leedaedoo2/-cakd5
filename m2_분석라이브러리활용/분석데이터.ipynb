# %%
import pandas as pd
import numpy as np
t3 = pd.read_csv('./visualization/dataset/titanic3.csv')
t3
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.00      0      0   24160  211.3375       B5        S    2
# 1       male   0.92      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.00      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.00      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.00      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...    ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.50      1      0    2665   14.4542      NaN        C  NaN
# 1305  female    NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.50      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.00      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.00      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
# 호칭 데이터 분석
import re

p = re.compile('[A-Z][a-z]+[.]')


namelist = list(t3['name'])
callname = []

for i in range(len(namelist)):
    
    m = p.findall(namelist[i])
    callname.append(m[0])


print(len(callname))

t3['callname'] = callname
t3
# Out:
# 1309
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.00      0      0   24160  211.3375       B5        S    2
# 1       male   0.92      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.00      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.00      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.00      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...    ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.50      1      0    2665   14.4542      NaN        C  NaN
# 1305  female    NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.50      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.00      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.00      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest callname
# 0       NaN                     St Louis, MO    Miss.
# 1       NaN  Montreal, PQ / Chesterville, ON  Master.
# 2       NaN  Montreal, PQ / Chesterville, ON    Miss.
# 3     135.0  Montreal, PQ / Chesterville, ON      Mr.
# 4       NaN  Montreal, PQ / Chesterville, ON     Mrs.
# ...     ...                              ...      ...
# 1304  328.0                              NaN    Miss.
# 1305    NaN                              NaN    Miss.
# 1306  304.0                              NaN      Mr.
# 1307    NaN                              NaN      Mr.
# 1308    NaN                              NaN      Mr.
#
# [1309 rows x 15 columns]

# %%
# 성씨 데이터 분석
pp = re.compile('[A-Z].+[,]')
ppp = re.compile('[A-Z].+[a-z]')
namelist = list(t3['name'])
surname = []

for i in range(len(namelist)):
    mm = pp.findall(namelist[i])
    mmm = ppp.findall(mm[0])
    surname.append(mmm[0])
    

print(len(surname))
    
t3['surname'] = surname
t3
# Out:
# 1309
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.00      0      0   24160  211.3375       B5        S    2
# 1       male   0.92      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.00      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.00      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.00      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...    ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.50      1      0    2665   14.4542      NaN        C  NaN
# 1305  female    NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.50      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.00      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.00      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest callname    surname
# 0       NaN                     St Louis, MO    Miss.      Allen
# 1       NaN  Montreal, PQ / Chesterville, ON  Master.    Allison
# 2       NaN  Montreal, PQ / Chesterville, ON    Miss.    Allison
# 3     135.0  Montreal, PQ / Chesterville, ON      Mr.    Allison
# 4       NaN  Montreal, PQ / Chesterville, ON     Mrs.    Allison
# ...     ...                              ...      ...        ...
# 1304  328.0                              NaN    Miss.     Zabour
# 1305    NaN                              NaN    Miss.     Zabour
# 1306  304.0                              NaN      Mr.   Zakarian
# 1307    NaN                              NaN      Mr.   Zakarian
# 1308    NaN                              NaN      Mr.  Zimmerman
#
# [1309 rows x 16 columns]

# %%
# age의 nan 값을 칭호별로 탐색
t3.loc[t3['age'].isnull()].value_counts('callname')
# Out:
# callname
# Mr.        176
# Miss.       50
# Mrs.        27
# Master.      8
# Dr.          1
# Ms.          1
# dtype: int64

# %%
#'Ms.'를 'Miss.'로 편입
t3.loc[t3['callname']=='Ms.',['callname']] = 'Miss.'

# %%
#null값이 1인 Dr.를 평균값으로 대체
c1 = t3['callname']=='Dr.'
c2 = t3['age'].isnull()
c3 = t3['age'].notnull()
mean = t3.loc[c1&c3,['age']].mean()
print(mean[0],type(mean[0]))
t3.loc[c1&c2,['age']] = mean[0]
# Out:
# 43.57142857142857 <class 'numpy.float64'>

# %%
nullcallname =  np.unique(t3.loc[t3['age'].isnull(),['callname']].values)
nullcallname = list(nullcallname)
nullcallname
# Out:
# ['Master.', 'Miss.', 'Mr.', 'Mrs.']

# %%
t3['embarked'].fillna(method='ffill',inplace=True)

# %%
t3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1047 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1309 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
#  14  callname   1309 non-null   object
#  15  surname    1309 non-null   object
# dtypes: float64(3), int64(4), object(9)
# memory usage: 163.8+ KB

# %%
embarklist =  np.unique(t3.embarked.values)
embarklist = list(embarklist)
embarklist
# Out:
# ['C', 'Q', 'S']

# %%
# age의 null값을 카테고리별로 연령의 평균값을 계산해 적용
# parch = 0 and sibsp = 0
for callname in nulllist:
    for a in range(3):
        for b in range(2):
            for embark in embarklist:
                mean = 0
                c1 = (t3['callname']==callname)
                c2 = (t3['age'].notnull())
                c3 = (t3['parch']==0)
                c4 = (t3['sibsp']==0)
                c5 = (t3['pclass']==a+1)
                c6 = (t3['survived']==b)
                c7 = (t3['embarked']==embark)
                mean = t3.loc[c1&c2&c3&c4&c5&c6&c7].age.mean()
                print(mean,type(mean))
                if type(mean) == np.float64:
                    print(mean.round())
                    c2 = (t3['age'].isnull())
                    t3.loc[c1&c2&c3&c4&c5&c6&c7,['age']] = mean.round()
# Out:
# 43.57142857142857 <class 'numpy.float64'>
# 44.0
# nan <class 'float'>
# nan <class 'float'>
# 32.0 <class 'numpy.float64'>
# 32.0
# nan <class 'float'>
# 49.0 <class 'numpy.float64'>
# 49.0
# nan <class 'float'>
# nan <class 'float'>
# 38.5 <class 'numpy.float64'>
# 38.0
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 43.0 <class 'numpy.float64'>
# 43.0
# nan <class 'float'>
# nan <class 'float'>
# 36.0 <class 'numpy.float64'>
# 36.0
# nan <class 'float'>
# 30.352941176470587 <class 'numpy.float64'>
# 30.0
# nan <class 'float'>
# nan <class 'float'>
# 31.0 <class 'numpy.float64'>
# 31.0
# 17.0 <class 'numpy.float64'>
# 17.0
# 30.0 <class 'numpy.float64'>
# 30.0
# 28.975 <class 'numpy.float64'>
# 29.0
# 17.0 <class 'numpy.float64'>
# 17.0
# 25.09090909090909 <class 'numpy.float64'>
# 25.0
# 25.36842105263158 <class 'numpy.float64'>
# 25.0
# 14.0 <class 'numpy.float64'>
# 14.0
# 20.5 <class 'numpy.float64'>
# 20.0
# 21.11111111111111 <class 'numpy.float64'>
# 21.0
# 42.05882352941177 <class 'numpy.float64'>
# 42.0
# nan <class 'float'>
# 44.72857142857143 <class 'numpy.float64'>
# 45.0
# 34.142857142857146 <class 'numpy.float64'>
# 34.0
# nan <class 'float'>
# 41.46153846153846 <class 'numpy.float64'>
# 41.0
# 31.75 <class 'numpy.float64'>
# 32.0
# 52.666666666666664 <class 'numpy.float64'>
# 53.0
# 31.234177215189874 <class 'numpy.float64'>
# 31.0
# 26.333333333333332 <class 'numpy.float64'>
# 26.0
# nan <class 'float'>
# 33.42857142857143 <class 'numpy.float64'>
# 33.0
# 27.325 <class 'numpy.float64'>
# 27.0
# 33.88461538461539 <class 'numpy.float64'>
# 34.0
# 28.656593406593405 <class 'numpy.float64'>
# 29.0
# 24.0 <class 'numpy.float64'>
# 24.0
# 25.0 <class 'numpy.float64'>
# 25.0
# 27.151515151515152 <class 'numpy.float64'>
# 27.0
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 54.833333333333336 <class 'numpy.float64'>
# 55.0
# nan <class 'float'>
# 48.0 <class 'numpy.float64'>
# 48.0
# nan <class 'float'>
# nan <class 'float'>
# 36.333333333333336 <class 'numpy.float64'>
# 36.0
# 23.0 <class 'numpy.float64'>
# 23.0
# nan <class 'float'>
# 35.81818181818182 <class 'numpy.float64'>
# 36.0
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 33.666666666666664 <class 'numpy.float64'>
# 34.0
# nan <class 'float'>
# 47.0 <class 'numpy.float64'>
# 47.0

# %%
for callname in nulllist:
    for a in range(3):
        for b in range(2):
            for embark in embarklist:
                mean = 0
                c1 = (t3['callname']==callname)
                c2 = (t3['age'].notnull())
                c3 = (t3['parch']!=0)
                c4 = (t3['sibsp']==0)
                c5 = (t3['pclass']==a+1)
                c6 = (t3['survived']==b)
                c7 = (t3['embarked']==embark)
                mean = t3.loc[c1&c2&c3&c4&c5&c6&c7].age.mean()
                print(mean,type(mean))
                if type(mean) == np.float64:
                    print(mean.round())
                    c2 = (t3['age'].isnull())
                    t3.loc[c1&c2&c3&c4&c5&c6&c7,['age']] = mean.round()
# Out:
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 6.0 <class 'numpy.float64'>
# 6.0
# nan <class 'float'>
# 4.0 <class 'numpy.float64'>
# 4.0
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 1.0 <class 'numpy.float64'>
# 1.0
# nan <class 'float'>
# 4.415 <class 'numpy.float64'>
# 4.0
# nan <class 'float'>
# nan <class 'float'>
# 6.665 <class 'numpy.float64'>
# 7.0
# 0.42 <class 'numpy.float64'>
# 0.0
# nan <class 'float'>
# 6.2075 <class 'numpy.float64'>
# 6.0
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 20.5 <class 'numpy.float64'>
# 20.0
# nan <class 'float'>
# 22.428571428571427 <class 'numpy.float64'>
# 22.0
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 13.25 <class 'numpy.float64'>
# 13.0
# 18.0 <class 'numpy.float64'>
# 18.0
# nan <class 'float'>
# 6.0 <class 'numpy.float64'>
# 6.0
# 2.5 <class 'numpy.float64'>
# 2.0
# nan <class 'float'>
# 7.666666666666667 <class 'numpy.float64'>
# 8.0
# 43.666666666666664 <class 'numpy.float64'>
# 44.0
# nan <class 'float'>
# 37.666666666666664 <class 'numpy.float64'>
# 38.0
# 24.25 <class 'numpy.float64'>
# 24.0
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 39.75 <class 'numpy.float64'>
# 40.0
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 39.0 <class 'numpy.float64'>
# 39.0
# nan <class 'float'>
# 42.166666666666664 <class 'numpy.float64'>
# 42.0
# 39.0 <class 'numpy.float64'>
# 39.0
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 48.125 <class 'numpy.float64'>
# 48.0
# nan <class 'float'>
# 50.666666666666664 <class 'numpy.float64'>
# 51.0
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 36.5 <class 'numpy.float64'>
# 36.0
# 45.0 <class 'numpy.float64'>
# 45.0
# 39.0 <class 'numpy.float64'>
# 39.0
# 34.6 <class 'numpy.float64'>
# 35.0
# 26.5 <class 'numpy.float64'>
# 26.0
# nan <class 'float'>
# 26.4 <class 'numpy.float64'>
# 26.0

# %%
for callname in nulllist:
    for a in range(3):
        for b in range(2):
            for embark in embarklist:
                mean = 0
                c1 = (t3['callname']==callname)
                c2 = (t3['age'].notnull())
                c3 = (t3['parch']==0)
                c4 = (t3['sibsp']!=0)
                c5 = (t3['pclass']==a+1)
                c6 = (t3['survived']==b)
                c7 = (t3['embarked']==embark)
                mean = t3.loc[c1&c2&c3&c4&c5&c6&c7].age.mean()
                print(mean,type(mean))
                if type(mean) == np.float64:
                    print(mean.round())
                    c2 = (t3['age'].isnull())
                    t3.loc[c1&c2&c3&c4&c5&c6&c7,['age']] = mean.round()
# Out:
# nan <class 'float'>
# 44.0 <class 'numpy.float64'>
# 44.0
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 50.0 <class 'numpy.float64'>
# 50.0
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 12.0 <class 'numpy.float64'>
# 12.0
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 36.0 <class 'numpy.float64'>
# 36.0
# 33.0 <class 'numpy.float64'>
# 33.0
# 63.0 <class 'numpy.float64'>
# 63.0
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 28.5 <class 'numpy.float64'>
# 28.0
# nan <class 'float'>
# 20.0 <class 'numpy.float64'>
# 20.0
# 14.5 <class 'numpy.float64'>
# 14.0
# nan <class 'float'>
# 22.166666666666668 <class 'numpy.float64'>
# 22.0
# 14.0 <class 'numpy.float64'>
# 14.0
# nan <class 'float'>
# 19.0 <class 'numpy.float64'>
# 19.0
# 42.25 <class 'numpy.float64'>
# 42.0
# nan <class 'float'>
# 38.916666666666664 <class 'numpy.float64'>
# 39.0
# 39.142857142857146 <class 'numpy.float64'>
# 39.0
# nan <class 'float'>
# 35.0 <class 'numpy.float64'>
# 35.0
# 30.5 <class 'numpy.float64'>
# 30.0
# nan <class 'float'>
# 32.416666666666664 <class 'numpy.float64'>
# 32.0
# nan <class 'float'>
# nan <class 'float'>
# 32.0 <class 'numpy.float64'>
# 32.0
# 23.666666666666668 <class 'numpy.float64'>
# 24.0
# nan <class 'float'>
# 26.958333333333332 <class 'numpy.float64'>
# 27.0
# nan <class 'float'>
# nan <class 'float'>
# 27.166666666666668 <class 'numpy.float64'>
# 27.0
# nan <class 'float'>
# nan <class 'float'>
# 63.0 <class 'numpy.float64'>
# 63.0
# 37.23076923076923 <class 'numpy.float64'>
# 37.0
# 37.0 <class 'numpy.float64'>
# 37.0
# 38.666666666666664 <class 'numpy.float64'>
# 39.0
# nan <class 'float'>
# nan <class 'float'>
# 40.0 <class 'numpy.float64'>
# 40.0
# 22.0 <class 'numpy.float64'>
# 22.0
# nan <class 'float'>
# 29.555555555555557 <class 'numpy.float64'>
# 30.0
# nan <class 'float'>
# nan <class 'float'>
# 30.142857142857142 <class 'numpy.float64'>
# 30.0
# 15.0 <class 'numpy.float64'>
# 15.0
# nan <class 'float'>
# 34.5 <class 'numpy.float64'>
# 34.0

# %%
for callname in nulllist:
    for a in range(3):
        for b in range(2):
            for embark in embarklist:
                mean = 0
                c1 = (t3['callname']==callname)
                c2 = (t3['age'].notnull())
                c3 = (t3['parch']!=0)
                c4 = (t3['sibsp']!=0)
                c5 = (t3['pclass']==a+1)
                c6 = (t3['survived']==b)
                c7 = (t3['embarked']==embark)
                mean = t3.loc[c1&c2&c3&c4&c5&c6&c7].age.mean()
                print(mean,type(mean))
                if type(mean) == np.float64:
                    print(mean.round())
                    c2 = (t3['age'].isnull())
                    t3.loc[c1&c2&c3&c4&c5&c6&c7,['age']] = mean.round()
# Out:
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 53.0 <class 'numpy.float64'>
# 53.0
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 13.0 <class 'numpy.float64'>
# 13.0
# nan <class 'float'>
# 5.96 <class 'numpy.float64'>
# 6.0
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 2.5625 <class 'numpy.float64'>
# 3.0
# 6.0 <class 'numpy.float64'>
# 6.0
# 6.2 <class 'numpy.float64'>
# 6.0
# 6.514705882352941 <class 'numpy.float64'>
# 7.0
# 7.0 <class 'numpy.float64'>
# 7.0
# nan <class 'float'>
# 4.0 <class 'numpy.float64'>
# 4.0
# nan <class 'float'>
# nan <class 'float'>
# 2.0 <class 'numpy.float64'>
# 2.0
# 26.0 <class 'numpy.float64'>
# 26.0
# nan <class 'float'>
# 22.25 <class 'numpy.float64'>
# 22.0
# nan <class 'float'>
# nan <class 'float'>
# 18.0 <class 'numpy.float64'>
# 18.0
# 2.0 <class 'numpy.float64'>
# 2.0
# nan <class 'float'>
# 11.72 <class 'numpy.float64'>
# 12.0
# 9.0 <class 'numpy.float64'>
# 9.0
# nan <class 'float'>
# 9.375 <class 'numpy.float64'>
# 9.0
# 3.875 <class 'numpy.float64'>
# 4.0
# nan <class 'float'>
# 4.695 <class 'numpy.float64'>
# 5.0
# 49.25 <class 'numpy.float64'>
# 49.0
# nan <class 'float'>
# 46.166666666666664 <class 'numpy.float64'>
# 46.0
# 52.5 <class 'numpy.float64'>
# 52.0
# nan <class 'float'>
# 36.5 <class 'numpy.float64'>
# 36.0
# 28.0 <class 'numpy.float64'>
# 28.0
# nan <class 'float'>
# 37.875 <class 'numpy.float64'>
# 38.0
# nan <class 'float'>
# nan <class 'float'>
# 26.0 <class 'numpy.float64'>
# 26.0
# 16.0 <class 'numpy.float64'>
# 16.0
# 40.0 <class 'numpy.float64'>
# 40.0
# 26.125 <class 'numpy.float64'>
# 26.0
# 20.0 <class 'numpy.float64'>
# 20.0
# nan <class 'float'>
# 29.0 <class 'numpy.float64'>
# 29.0
# nan <class 'float'>
# nan <class 'float'>
# 25.0 <class 'numpy.float64'>
# 25.0
# 42.0 <class 'numpy.float64'>
# 42.0
# nan <class 'float'>
# 47.111111111111114 <class 'numpy.float64'>
# 47.0
# nan <class 'float'>
# nan <class 'float'>
# 26.0 <class 'numpy.float64'>
# 26.0
# 23.0 <class 'numpy.float64'>
# 23.0
# nan <class 'float'>
# 35.5 <class 'numpy.float64'>
# 36.0
# nan <class 'float'>
# 32.0 <class 'numpy.float64'>
# 32.0
# 37.42857142857143 <class 'numpy.float64'>
# 37.0
# 17.5 <class 'numpy.float64'>
# 18.0
# nan <class 'float'>
# 30.833333333333332 <class 'numpy.float64'>
# 31.0

# %%
for callname in nulllist:
    c1 = t3['age'].notnull()
    c2 = t3['callname'] == callname
    
    mean = t3.loc[c1&c2,'age'].mean()
    print(mean)
    c1 = t3['age'].isnull()
    t3.loc[c1&c2,['age']] = mean.round()
# Out:
# 43.57142857142857
# 5.659666666666666
# 21.402313725490195
# 32.077896138482025
# 37.19371727748691

# %%
callname_group = t3.groupby('callname').mean()
callname_group['age'].round()
# Out:
# callname
# Capt.        70.0
# Col.         54.0
# Countess.    33.0
# Don.         40.0
# Dona.        39.0
# Dr.          44.0
# Jonkheer.    38.0
# Lady.        48.0
# Major.       48.0
# Master.       6.0
# Miss.        21.0
# Mlle.        24.0
# Mme.         24.0
# Mr.          32.0
# Mrs.         37.0
# Rev.         41.0
# Sir.         49.0
# Name: age, dtype: float64

# %%
def age_cat(x):
    cat = ''
    if x<10:
        cat = 'child'
    elif x<20:
        cat = 'teen'
    elif x<30:
        cat = '20s'
    elif x<40:
        cat = '30s'
    elif x<50:
        cat = '40s'
    elif x<60:
        cat = '50s'
    else:
        cat = 'eldery'
    return cat

t3['age_cat'] = t3.age.apply(lambda x:age_cat(x))
t3.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest callname  surname age_cat
# 0                     St Louis, MO    Miss.    Allen     20s
# 1  Montreal, PQ / Chesterville, ON  Master.  Allison   child
# 2  Montreal, PQ / Chesterville, ON    Miss.  Allison   child
# 3  Montreal, PQ / Chesterville, ON      Mr.  Allison     30s
# 4  Montreal, PQ / Chesterville, ON     Mrs.  Allison     20s

# %%
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')
le = LabelEncoder()
t3['age_cat_label'] = le.fit_transform(t3['age_cat'])
t3
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.00      0      0   24160  211.3375       B5        S    2
# 1       male   0.92      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.00      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.00      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.00      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...    ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.50      1      0    2665   14.4542      NaN        C  NaN
# 1305  female  14.00      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.50      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.00      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.00      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest callname    surname age_cat  \
# 0       NaN                     St Louis, MO    Miss.      Allen     20s
# 1       NaN  Montreal, PQ / Chesterville, ON  Master.    Allison   child
# 2       NaN  Montreal, PQ / Chesterville, ON    Miss.    Allison   child
# 3     135.0  Montreal, PQ / Chesterville, ON      Mr.    Allison     30s
# 4       NaN  Montreal, PQ / Chesterville, ON     Mrs.    Allison     20s
# ...     ...                              ...      ...        ...     ...
# 1304  328.0                              NaN    Miss.     Zabour    teen
# 1305    NaN                              NaN    Miss.     Zabour    teen
# 1306  304.0                              NaN      Mr.   Zakarian     20s
# 1307    NaN                              NaN      Mr.   Zakarian     20s
# 1308    NaN                              NaN      Mr.  Zimmerman     20s
#
#       age_cat_label
# 0                 0
# 1                 4
# 2                 4
# 3                 1
# 4                 0
# ...             ...
# 1304              6
# 1305              6
# 1306              0
# 1307              0
# 1308              0
#
# [1309 rows x 18 columns]

# %%
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')
le = LabelEncoder()
t3.boat.fillna('0',inplace=True)
t3['boat_label'] = le.fit_transform(t3['boat'])
t3
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.00      0      0   24160  211.3375       B5        S    2
# 1       male   0.92      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.00      1      2  113781  151.5500  C22 C26        S    0
# 3       male  30.00      1      2  113781  151.5500  C22 C26        S    0
# 4     female  25.00      1      2  113781  151.5500  C22 C26        S    0
# ...      ...    ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.50      1      0    2665   14.4542        0        C    0
# 1305  female  14.00      1      0    2665   14.4542        0        C    0
# 1306    male  26.50      0      0    2656    7.2250        0        C    0
# 1307    male  27.00      0      0    2670    7.2250        0        C    0
# 1308    male  29.00      0      0  315082    7.8750        0        S    0
#
#        body                        home.dest callname    surname age_cat  \
# 0       NaN                     St Louis, MO    Miss.      Allen     20s
# 1       NaN  Montreal, PQ / Chesterville, ON  Master.    Allison   child
# 2       NaN  Montreal, PQ / Chesterville, ON    Miss.    Allison   child
# 3     135.0  Montreal, PQ / Chesterville, ON      Mr.    Allison     30s
# 4       NaN  Montreal, PQ / Chesterville, ON     Mrs.    Allison     20s
# ...     ...                              ...      ...        ...     ...
# 1304  328.0                              NaN    Miss.     Zabour    teen
# 1305    NaN                              NaN    Miss.     Zabour    teen
# 1306  304.0                              NaN      Mr.   Zakarian     20s
# 1307    NaN                              NaN      Mr.   Zakarian     20s
# 1308    NaN                              NaN      Mr.  Zimmerman     20s
#
#       age_cat_label  cabin_label  boat_label
# 0                 0           44          12
# 1                 4           80           3
# 2                 4           80           0
# 3                 1           80           0
# 4                 0           80           0
# ...             ...          ...         ...
# 1304              6            0           0
# 1305              6            0           0
# 1306              0            0           0
# 1307              0            0           0
# 1308              0            0           0
#
# [1309 rows x 20 columns]

# %%
df1 = pd.read_pickle('./visualization/dataset/tdf.pkl')
df1.age_cat = t3.age_cat_label
df1['boat'] = t3.boat_label
df1
# Out:
#       survived  fare_cat  age_cat  family  female  male  town_C  town_Q  \
# 0            1         1        0       0       1     0       0       0
# 1            1         1        4       3       0     1       0       0
# 2            0         1        4       3       1     0       0       0
# 3            0         1        1       3       0     1       0       0
# 4            0         1        0       3       1     0       0       0
# ...        ...       ...      ...     ...     ...   ...     ...     ...
# 1304         0         3        6       1       1     0       1       0
# 1305         0         3        6       1       1     0       1       0
# 1306         0         4        0       0       0     1       1       0
# 1307         0         4        0       0       0     1       1       0
# 1308         0         4        0       0       0     1       0       0
#
#       town_S  boat
# 0          1    12
# 1          1     3
# 2          1     0
# 3          1     0
# 4          1     0
# ...      ...   ...
# 1304       0     0
# 1305       0     0
# 1306       0     0
# 1307       0     0
# 1308       1     0
#
# [1309 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

#독립변수, 종속 변수 분리

y_df = df1['survived'] #종속 변수
X_df = df1.drop('survived',axis = 1) # 독립변수

# 학습용 데이터와 평가용 데이터를 8:2 혹은 7:3으로 분리

X_train, X_test, y_train, y_test = train_test_split(X_df,y_df,test_size =0.3, random_state= 11)
print(X_train.shape)
print(X_test.shape)
# Out:
# (916, 9)
# (393, 9)

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier()


rf_model.fit(X_train,y_train)

# 예측값 추출
rf_pred = rf_model.predict(X_test)

# 예측값과 실제값 비교
accuracy_rf = accuracy_score(y_test,rf_pred).round(2)

lr_model = LogisticRegression()
lr_model.fit(X_train,y_train)
lr_pred = lr_model.predict(X_test)
accuracy_lr = accuracy_score(y_test,lr_pred).round(2)


print(f'rf 정확도 : {accuracy_rf},lr 정확도 : {accuracy_lr}')
# Out:
# rf 정확도 : 0.97,lr 정확도 : 0.96

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,15))
sns.heatmap(t3.corr(),annot=True)
plt.title('Heatmap of the Dataset',fontsize=10)
# Out:
# Text(0.5, 1.0, 'Heatmap of the Dataset')
