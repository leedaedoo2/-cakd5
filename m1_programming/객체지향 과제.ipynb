# %%
import numpy as np
mymoney =50000
bankmoney = 0


print('인생 게임에 온 것을 환영합니다?')
while 1:
    if mymoney == 0 and bankmoney == 0:
        print('HAHAHA 당신은 이제 끝장입니다!')
        break
    
    
    choice1 = input('어디로 갈까요? 1.은행 2.도박장 3.금액 확인> ')
    if choice1 not in ['1','2','3']:
        print('다시 누르세요')
        
        continue
    elif choice1 == '1':
        while 1:
            choice2 = input('무엇을 할까요? 1.저금액 확인 2.저금 3.인출 아무거나 눌러서 뒤로 갑니다> ')
            if choice2 == '1':
                print('현재 저금액 : ',bankmoney)
                continue
            elif choice2 == '2':
                while 1:
                    try:
                        depositmoney = input('저금할 금액을 적어주세요 (0을 눌러 취소)> ')
                        
                        if int(depositmoney) > mymoney:
                            print('금액이 부족합니다')
                        elif int(depositmoney) == 0:
                            print('저금을 취소합니다')
                            break
                        else:
                            print(f'{depositmoney}원 저금합니다')
                            mymoney -= int(depositmoney)
                            bankmoney += int(depositmoney)
                            break
                    except:
                        print('다시 적어주세요')
                        continue
                    
            elif choice2 == '3':
                while 1:
                    try:
                        withdrawmoney = input('인출할 금액을 적어주세요 (0을 눌러 취소)> ')
                        
                        if int(withdrawmoney) > bankmoney:
                            print('금액이 부족합니다')
                        elif int(withdrawmoney) == 0:
                            print('인출을 취소합니다')
                            break
                        else:
                            print(f'{withdrawmoney}원 인출합니다')
                            bankmoney -= int(withdrawmoney)
                            mymoney += int(withdrawmoney)
                            break
                    except:
                        print('다시 적어주세요')
                        continue
            else:
                break
    elif choice1 == '3':
        print(f'현재 소지금 :{mymoney}원')
        continue
    elif choice1 == '2':
        while 1:
            print('코인 토스 도박장에 오신 것을 환영합니다!!!!!')
            choice3 = input('한번 던지실까요??> [y/n]')
            if choice3 not in ['y','n']:
                print('다시 골라주세요!')
                continue
            elif choice3 == 'n':
                print('그럼 안녕히가세요!')
                break
            else:
                while 1:
                    try:
                        bet = input('그럼 얼마를 걸어보실까요?? (0을 눌러 뒤로가기)> ')
                        
                        if int(bet) > mymoney:
                            print('이럴수가! 돈이 부족하군요!')
                            continue
                        elif int(bet) == 0:
                            print('그럼 충분히 생각해주세요!')
                            break
                        else:
                            print('그가 던졌습니다!')
                            mymoney -= int(bet)
                            coin = np.random.randint(2)
                            result = 0
                            if coin ==0:
                                print('앞면이 나왔습니다')
                                print('당첨금 두배')
                                result += 2*int(bet)
                            else:
                                print('뒷면이 나왔습니다')
                                print('꽝입니다')
                            mymoney += result
                            print(f'{int(bet)}원 내고 {result}원 벌었습니다!')
                            print('그러는 동안 하루가 지났네요...(대충 이자 들어왔다는 소리)')
                            interest = np.random.randint(6)
                            bankmoney *= (1+0.01*interest)
                            bankmoney=round(bankmoney)
                            break
                    except:
                        print('잘못 누르셨네요!')
                        continue
# Out:
# 어디로 갈까요? 1.은행 2.도박장 3.금액 확인> 1
# 무엇을 할까요? 1.저금액 확인 2.저금 3.인출 아무거나 눌러서 뒤로 갑니다> 1
# 현재 저금액 :  0
# 무엇을 할까요? 1.저금액 확인 2.저금 3.인출 아무거나 눌러서 뒤로 갑니다> 2
# 저금할 금액을 적어주세요 (0을 눌러 취소)> 30000
# 30000원 저금합니다
# 무엇을 할까요? 1.저금액 확인 2.저금 3.인출 아무거나 눌러서 뒤로 갑니다> e
# 어디로 갈까요? 1.은행 2.도박장 3.금액 확인> 3
# 현재 소지금 :20000원
# 어디로 갈까요? 1.은행 2.도박장 3.금액 확인> 2
# 코인 토스 도박장에 오신 것을 환영합니다!!!!!
# 한번 던지실까요??> [y/n]y
# 그럼 얼마를 걸어보실까요?? (0을 눌러 뒤로가기)> 10000
# 그가 던졌습니다!
# 앞면이 나왔습니다
# 당첨금 두배
# 10000원 내고 20000원 벌었습니다!
# 그러는 동안 하루가 지났네요...(대충 이자 들어왔다는 소리)
# 코인 토스 도박장에 오신 것을 환영합니다!!!!!
# 한번 던지실까요??> [y/n]y
# 그럼 얼마를 걸어보실까요?? (0을 눌러 뒤로가기)> 10000
# 그가 던졌습니다!
# 뒷면이 나왔습니다
# 꽝입니다
# 10000원 내고 0원 벌었습니다!
# 그러는 동안 하루가 지났네요...(대충 이자 들어왔다는 소리)
# 코인 토스 도박장에 오신 것을 환영합니다!!!!!
# 한번 던지실까요??> [y/n]n
# 그럼 안녕히가세요!
# 어디로 갈까요? 1.은행 2.도박장 3.금액 확인> 3
# 현재 소지금 :20000원
# 어디로 갈까요? 1.은행 2.도박장 3.금액 확인> 1
# 무엇을 할까요? 1.저금액 확인 2.저금 3.인출 아무거나 눌러서 뒤로 갑니다> 1
# 현재 저금액 :  30900
# 무엇을 할까요? 1.저금액 확인 2.저금 3.인출 아무거나 눌러서 뒤로 갑니다> 3
# 인출할 금액을 적어주세요 (0을 눌러 취소)> 30900
# 30900원 인출합니다
# 무엇을 할까요? 1.저금액 확인 2.저금 3.인출 아무거나 눌러서 뒤로 갑니다> e
# 어디로 갈까요? 1.은행 2.도박장 3.금액 확인> 2
# 코인 토스 도박장에 오신 것을 환영합니다!!!!!
# 한번 던지실까요??> [y/n]y
# 그럼 얼마를 걸어보실까요?? (0을 눌러 뒤로가기)> 0
# 그럼 충분히 생각해주세요!
# 코인 토스 도박장에 오신 것을 환영합니다!!!!!
# 한번 던지실까요??> [y/n]n
# 그럼 안녕히가세요!
# 어디로 갈까요? 1.은행 2.도박장 3.금액 확인> 3
# 현재 소지금 :50900원
# 어디로 갈까요? 1.은행 2.도박장 3.금액 확인> 2
# 코인 토스 도박장에 오신 것을 환영합니다!!!!!
# 한번 던지실까요??> [y/n]y
# 그럼 얼마를 걸어보실까요?? (0을 눌러 뒤로가기)> 50900
# 그가 던졌습니다!
# 앞면이 나왔습니다
# 당첨금 두배
# 50900원 내고 101800원 벌었습니다!
# 그러는 동안 하루가 지났네요...(대충 이자 들어왔다는 소리)
# 코인 토스 도박장에 오신 것을 환영합니다!!!!!
# 한번 던지실까요??> [y/n]y
# 그럼 얼마를 걸어보실까요?? (0을 눌러 뒤로가기)> 101800
# 그가 던졌습니다!
# 앞면이 나왔습니다
# 당첨금 두배
# 101800원 내고 203600원 벌었습니다!
# 그러는 동안 하루가 지났네요...(대충 이자 들어왔다는 소리)
# 코인 토스 도박장에 오신 것을 환영합니다!!!!!
# 한번 던지실까요??> [y/n]y
# 그럼 얼마를 걸어보실까요?? (0을 눌러 뒤로가기)> 203600
# 그가 던졌습니다!
# 뒷면이 나왔습니다
# 꽝입니다
# 203600원 내고 0원 벌었습니다!
# 그러는 동안 하루가 지났네요...(대충 이자 들어왔다는 소리)
# 코인 토스 도박장에 오신 것을 환영합니다!!!!!
# 한번 던지실까요??> [y/n]n
# 그럼 안녕히가세요!
# HAHAHA 당신은 이제 끝장입니다!

# %%
import numpy as np


class Bank:
    bankmoney = 0
    def viewmoney(self):
        return self.bankmoney
    def deposit(self,money):
        self.bankmoney += money
        
    def withdraw(self,money):
        if self.bankmoney < money:
            print('인출 금액이 부족합니다')
            return 0
        else:
            self.bankmoney -= money
            return money
    def interest(self):
        a = np.random.randint(6)
        a = 1+0.01*a
        self.bankmoney *= a
        self.bankmoney = round(self.bankmoney)

class Coin:
    def cointoss(self):
        x = np.random.randint(2)
        return x
    def coinresult(self,x,money):
        rest = 0
        if x == 0:
            print('앞면이 나왔습니다')
            print('당첨금 두배')
            rest +=  2*money
        elif x == 1:
            print('꽝입니다')
            rest +=  0
        return rest
    
    
class Man(Bank,Coin):
    def __init__(self):
        self.budget = 50000
    

person = Man()
print('인생 게임에 온 것을 환영합니다?')
while 1:
    if person.budget == 0 and person.bankmoney == 0:
        print('HAHAHA 당신은 이제 끝장입니다!')
        break
    
    
    choice1 = input('어디로 갈까요? 1.은행 2.도박장 3.금액 확인> ')
    if choice1 not in ['1','2','3']:
        print('다시 누르세요')
        
        continue
    elif choice1 == '1':
        while 1:
            choice2 = input('무엇을 할까요? 1.저금액 확인 2.저금 3.인출 아무거나 눌러서 뒤로 갑니다> ')
            if choice2 == '1':
                print('현재 저금액 : ',person.bankmoney)
                continue
            elif choice2 == '2':
                while 1:
                    try:
                        depositmoney = input('저금할 금액을 적어주세요 (0을 눌러 취소)> ')
                        
                        if int(depositmoney) > person.budget:
                            print('금액이 부족합니다')
                        elif int(depositmoney) == 0:
                            print('저금을 취소합니다')
                            break
                        else:
                            print(f'{depositmoney}원 저금합니다')
                            person.budget -=int(depositmoney)
                            person.deposit(int(depositmoney))
                            break
                    except:
                        print('다시 적어주세요')
                        continue
                    
            elif choice2 == '3':
                while 1:
                    try:
                        withdrawmoney = input('인출할 금액을 적어주세요 (0을 눌러 취소)> ')
                        
                        if int(withdrawmoney) > person.bankmoney:
                            print('금액이 부족합니다')
                        elif int(withdrawmoney) == 0:
                            print('인출을 취소합니다')
                            break
                        else:
                            print(f'{withdrawmoney}원 인출합니다')
                            person.budget += person.withdraw(int(withdrawmoney))
                            break
                    except:
                        print('다시 적어주세요')
                        continue
            else:
                break
    elif choice1 == '3':
        print(f'현재 소지금 :{person.budget}원')
        continue
    elif choice1 == '2':
        while 1:
            print('코인 토스 도박장에 오신 것을 환영합니다!!!!!')
            choice3 = input('한번 던지실까요??> [y/n]')
            if choice3 not in ['y','n']:
                print('다시 골라주세요!')
                continue
            elif choice3 == 'n':
                print('그럼 안녕히가세요!')
                break
            else:
                while 1:
                    try:
                        bet = input('그럼 얼마를 걸어보실까요?? (0을 눌러 뒤로가기)> ')
                        
                        if int(bet) > person.budget:
                            print('이럴수가! 돈이 부족하군요!')
                            continue
                        elif int(bet) == 0:
                            print('그럼 충분히 생각해주세요!')
                            break
                        else:
                            print('그가 던졌습니다!')
                            person.budget -= int(bet)
                            coin = person.cointoss()
                            result = person.coinresult(coin,int(bet))
                            person.budget += result
                            print(f'{int(bet)}원 내고 {result}원 벌었습니다!')
                            print('그러는 동안 하루가 지났네요...(대충 이자 들어왔다는 소리)')
                            person.interest()
                            break
                    except:
                        print('잘못 누르셨네요!')
                        continue
